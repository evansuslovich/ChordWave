# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: accelerate>=0.12.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: torch>=2.6.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: datasets>=2.14.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: protobuf in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: evaluate in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: scikit-learn in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.5.2)
# Requirement already satisfied: filelock in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: networkx in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: fsspec in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.6.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: pandas in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (4.67.0)
# Requirement already satisfied: xxhash in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: aiohttp in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from datasets>=2.14.0->-r requirements.txt (line 3)) (3.8.6)
# Requirement already satisfied: scipy>=1.5.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from aiohttp->datasets>=2.14.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.14.0->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.14.0->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.14.0->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from jinja2->torch>=2.6.0->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from pandas->datasets>=2.14.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from pandas->datasets>=2.14.0->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from pandas->datasets>=2.14.0->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.14.0->-r requirements.txt (line 3)) (1.16.0)

# %%
# !pip install torch --upgrade --index-url https://download.pytorch.org/whl/cpu
# !python -c "import torch; print(torch.__version__)"
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: filelock in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# 2.6.0

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.52.0.dev0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages
# Editable project location: /Users/evansuslovich/Desktop/all/school/spring25/CS4973/ChordWave/transformers
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by:

# %%
# !python run_clm.py \
    --model_name_or_path openai-community/gpt2 \
    --train_file "data/train_chords.csv" \
    --validation_file "data/val_chords.csv" \
    --per_device_train_batch_size 2 \
    --per_device_eval_batch_size 2 \
    --do_train \
    --do_eval \
    --output_dir /tmp/test-clm
# Out:
# /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <F263C8ED-23C1-35DD-BD33-2CD667C0ED1D> /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/torchvision/image.so
#   Expected in:     <25C510F7-7AEE-3D64-80ED-95874DC6BECD> /Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/torch/lib/libtorch_cpu.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 04/11/2025 17:33:22 - WARNING - __main__ - Process rank: 0, device: mps, n_gpu: 1, distributed training: False, 16-bits training: False
# 04/11/2025 17:33:22 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=False,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=IntervalStrategy.NO,
# eval_use_gather_object=False,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-clm/runs/Apr11_17-33-22_Evans-MacBook-Pro.local,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs={},
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH,
# optim_args=None,
# optim_target_modules=None,
# output_dir=/tmp/test-clm,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=2,
# per_device_train_batch_size=2,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=/tmp/test-clm,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_liger_kernel=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# 04/11/2025 17:33:22 - INFO - __main__ - Checkpoint detected, resuming training at /tmp/test-clm/checkpoint-117. To avoid this behavior, change the `--output_dir` or add `--overwrite_output_dir` to train from scratch.
# Traceback (most recent call last):
#   File "/Users/evansuslovich/Desktop/all/school/spring25/CS4973/ChordWave/run_clm.py", line 658, in <module>
#     main()
#   File "/Users/evansuslovich/Desktop/all/school/spring25/CS4973/ChordWave/run_clm.py", line 352, in main
#     raw_datasets = load_dataset(
#                    ^^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/load.py", line 2062, in load_dataset
#     builder_instance = load_dataset_builder(
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/load.py", line 1782, in load_dataset_builder
#     dataset_module = dataset_module_factory(
#                      ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/load.py", line 1497, in dataset_module_factory
#     ).get_module()
#       ^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/load.py", line 913, in get_module
#     data_files = DataFilesDict.from_patterns(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/data_files.py", line 690, in from_patterns
#     else DataFilesList.from_patterns(
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/data_files.py", line 583, in from_patterns
#     resolve_pattern(
#   File "/Users/evansuslovich/anaconda3/envs/ai/lib/python3.11/site-packages/datasets/data_files.py", line 384, in resolve_pattern
#     raise FileNotFoundError(error_msg)
# FileNotFoundError: Unable to find '/Users/evansuslovich/Desktop/all/school/spring25/CS4973/ChordWave/train_data_personal.csv'
